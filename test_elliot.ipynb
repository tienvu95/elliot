# %%
from elliot.run import run_experiment

run_experiment("/Users/vuhoang/Documents/code_base/elliot/config_files/demo_amazon_baby.yml")
# Out:
# __/\\\\\\\\\\\\\\\___/\\\\\\______/\\\\\\_________________________________________
#  _\/\\\///////////___\////\\\_____\////\\\_________________________________________
#   _\/\\\_________________\/\\\________\/\\\______/\\\_____________________/\\\______
#    _\/\\\\\\\\\\\_________\/\\\________\/\\\_____\///_______/\\\\\______/\\\\\\\\\\\_
#     _\/\\\///////__________\/\\\________\/\\\______/\\\____/\\\///\\\___\////\\\////__
#      _\/\\\_________________\/\\\________\/\\\_____\/\\\___/\\\__\//\\\_____\/\\\______
#       _\/\\\_________________\/\\\________\/\\\_____\/\\\__\//\\\__/\\\______\/\\\_/\\__
#        _\/\\\\\\\\\\\\\\\___/\\\\\\\\\___/\\\\\\\\\__\/\\\___\///\\\\\/_______\//\\\\\___
#         _\///////////////___\/////////___\/////////___\///______\/////__________\/////____
# Version Number: 0.3.1
# 2022-11-27 15:38:53.388890: I Start experiment
# 2022-11-27 15:38:53.440854: I /Users/vuhoang/Documents/code_base/elliot/data/amazon_baby/trainingset.tsv - Loaded
# 2022-11-27 15:38:53.484905: I Test Fold 0 - Validation Fold 0
# 2022-11-27 15:38:54.056061: I Statistics	Users:	606	Items:	1393	Transactions:	2670	Sparsity:	0.9968370850006752
# 2022-11-27 15:38:59.136522: I Tuning begun for VBPR\n
# 2022-11-27 15:38:59.138377: I Loading parameters
# 2022-11-27 15:38:59.139128: I Hyperparameter tuning exploration:
# 2022-11-27 15:38:59.140104: I l_w set to 1e-05
# 2022-11-27 15:38:59.140471: I Parameter batch_eval set to 4096
# 2022-11-27 15:38:59.141768: I lr set to 0.001
# 2022-11-27 15:38:59.142377: I Parameter factors set to 128
# 2022-11-27 15:38:59.143447: I Exploration: Hyperparameter exploration number 1
# 2022-11-27 15:38:59.144743: I Exploration: Test Fold exploration number 1
# 2022-11-27 15:38:59.143968: I Parameter factors_d set to 20
# 2022-11-27 15:38:59.146583: I Exploration: Train-Validation Fold exploration number 1
# 2022-11-27 15:38:59.147582: I Parameter lr set to 0.001
# 2022-11-27 15:38:59.149143: I Parameter l_w set to 1e-05
# 2022-11-27 15:38:59.150322: I Parameter l_b set to 0
# 2022-11-27 15:38:59.152675: I Parameter l_e set to 0.002
# 2022-11-27 15:38:59.153612: I Parameter loader set to VisualAttributes
#   0%|                                     | 0/20 [00:00<?, ?it/s, loss=39.90747]
# 2022-11-27 15:39:29.999948: I
# 2022-11-27 15:39:30.068866: I Validation Evaluation results
# 2022-11-27 15:39:30.154783: I Cut-off: 20
# 2022-11-27 15:39:30.235958: I Eval Time: 0.10701894760131836
# 2022-11-27 15:39:30.317920: I Results
# 2022-11-27 15:39:30.403811: I HR	0.0198
# 2022-11-27 15:39:30.475896: I nDCG	0.00581
# 2022-11-27 15:39:30.519223: I Precision	0.00099
# 2022-11-27 15:39:30.537959: I F1	0.00189
# 2022-11-27 15:39:30.574405: I MAP	0.0007
# 2022-11-27 15:39:30.634718: I ItemCoverage	721
# 2022-11-27 15:41:17.250944: I Eval Time: 0.3273899555206299
# 2022-11-27 15:41:17.287908: I Results
# 2022-11-27 15:41:17.369842: I HR	0.0297
# 2022-11-27 15:41:17.515456: I nDCG	0.00855
# 2022-11-27 15:41:17.541967: I Precision	0.00059
# 2022-11-27 15:41:17.582131: I F1	0.00116
# 2022-11-27 15:41:17.612704: I MAP	0.00071
# 2022-11-27 15:41:17.655299: I ItemCoverage	1336
# 2022-11-27 15:41:17.758470: I nDCGRendle2020	0.00855
# 2022-11-27 15:41:17.817023: I Gini	0.51211
# 2022-11-27 15:41:17.864036: I SEntropy	9.84897
# 2022-11-27 15:41:17.906988: I EFD	0.00646
# 2022-11-27 15:41:18.032517: I EPC	0.00066
# 2022-11-27 15:41:18.084130: I
# 2022-11-27 15:41:18.135774: I Test Evaluation results
# 2022-11-27 15:41:18.193466: I Cut-off: 50
# 2022-11-27 15:41:18.230623: I Eval Time: 0.3308289051055908
# 2022-11-27 15:41:18.285969: I Results
# 2022-11-27 15:41:18.350619: I HR	0.02805
# 2022-11-27 15:41:18.375460: I nDCG	0.0076
# 2022-11-27 15:41:18.451070: I Precision	0.00056
# 2022-11-27 15:41:18.495779: I F1	0.0011
# 2022-11-27 15:41:18.512379: I MAP	0.00067
# 2022-11-27 15:41:18.572678: I ItemCoverage	1336
# 2022-11-27 15:41:18.646335: I nDCGRendle2020	0.0076
# 2022-11-27 15:41:18.696467: I Gini	0.51211
# 2022-11-27 15:41:18.842507: I SEntropy	9.84897
# 2022-11-27 15:41:18.857637: I EFD	0.00609
# 2022-11-27 15:41:18.928217: I EPC	0.00059
# 2022-11-27 15:41:19.003214: I
# 2022-11-27 15:41:19.052009: I Validation Evaluation results
# 2022-11-27 15:41:19.125557: I Cut-off: 100
# 2022-11-27 15:41:19.219791: I Eval Time: 0.7630100250244141
# 2022-11-27 15:41:19.227009: I Results
# 2022-11-27 15:41:19.260179: I HR	0.06601
# 2022-11-27 15:41:19.318708: I nDCG	0.0143
# 2022-11-27 15:41:19.401545: I Precision	0.00066
# 2022-11-27 15:41:19.415912: I F1	0.00131
# 2022-11-27 15:41:19.469125: I MAP	0.00065
# 2022-11-27 15:41:19.546738: I ItemCoverage	1387
# 2022-11-27 15:41:19.614950: I nDCGRendle2020	0.0143
# 2022-11-27 15:41:19.650266: I Gini	0.61298
# 2022-11-27 15:41:19.715326: I SEntropy	10.08226
# 2022-11-27 15:41:19.751427: I EFD	0.0067
# 2022-11-27 15:41:19.820105: I EPC	0.00068
# 2022-11-27 15:41:19.839526: I
# 2022-11-27 15:41:19.866826: I Epoch 40/100 loss 0.17293
# 2022-11-27 15:41:19.874306: I Test Evaluation results
# 2022-11-27 15:41:19.873520: I Writing recommendations at: /Users/vuhoang/Documents/code_base/elliot/results/amazon_baby/recs
# 2022-11-27 15:41:19.883053: I Cut-off: 100
# 2022-11-27 15:41:19.893627: I Eval Time: 0.7780230045318604
# 2022-11-27 15:41:19.899021: I Results
# 2022-11-27 15:41:19.913017: I HR	0.06106
# 2022-11-27 15:41:19.921052: I nDCG	0.01282
# 2022-11-27 15:41:19.939203: I Precision	0.00061
# 2022-11-27 15:41:19.959291: I F1	0.00121
# 2022-11-27 15:41:19.971744: I MAP	0.00061
# 2022-11-27 15:41:19.984319: I ItemCoverage	1387
# 2022-11-27 15:41:19.989055: I nDCGRendle2020	0.01282
# 2022-11-27 15:41:20.003061: I Gini	0.61298
# 2022-11-27 15:41:20.012250: I SEntropy	10.08226
# 2022-11-27 15:41:20.026331: I EFD	0.00619
# 2022-11-27 15:41:20.051749: I EPC	0.00061
#   0%|                                      | 0/20 [00:00<?, ?it/s, loss=4.56276]
# 2022-11-27 15:41:49.833041: I
# 2022-11-27 15:41:49.897230: I Validation Evaluation results
# 2022-11-27 15:41:49.925630: I Cut-off: 20
# 2022-11-27 15:41:49.945682: I Eval Time: 0.1198129653930664
# 2022-11-27 15:41:49.982139: I Results
# 2022-11-27 15:41:50.073917: I HR	0.01155
# 2022-11-27 15:41:50.104572: I nDCG	0.00416
# 2022-11-27 15:41:50.149279: I Precision	0.00058
# 2022-11-27 15:41:50.182853: I F1	0.0011
# 2022-11-27 15:41:50.232807: I MAP	0.00067
# 2022-11-27 15:41:50.242799: I ItemCoverage	1183
# 2022-11-27 15:41:50.279248: I nDCGRendle2020	0.00416
# 2022-11-27 15:41:50.355711: I Gini	0.39488
# 2022-11-27 15:41:50.424429: I SEntropy	9.46803
# 2022-11-27 15:41:50.458554: I EFD	0.0058
# 2022-11-27 15:41:50.488563: I EPC	0.00058
# 2022-11-27 15:41:50.515478: I
# 2022-11-27 15:41:50.549623: I Test Evaluation results
# 2022-11-27 15:41:50.643639: I Cut-off: 20
# 2022-11-27 15:41:50.675352: I Eval Time: 0.1414508819580078
# 2022-11-27 15:41:50.725395: I Results
# 2022-11-27 15:41:50.822544: I HR	0.01155
# 2022-11-27 15:41:50.898822: I nDCG	0.00531
# 2022-11-27 15:41:50.983825: I Precision	0.00058
# 2022-11-27 15:41:51.080270: I F1	0.0011
# 2022-11-27 15:41:51.109795: I MAP	0.00093
# 2022-11-27 15:41:51.134113: I ItemCoverage	1183
# 2022-11-27 15:41:51.178789: I nDCGRendle2020	0.00531
# 2022-11-27 15:41:51.214518: I Gini	0.39488
# 2022-11-27 15:41:51.272015: I SEntropy	9.46803
# 2022-11-27 15:41:51.294315: I EFD	0.00766
# 2022-11-27 15:41:51.320809: I EPC	0.00075
# 2022-11-27 15:41:51.415526: I
# 2022-11-27 15:41:51.501885: I Validation Evaluation results
# 2022-11-27 15:41:51.522076: I Cut-off: 50
# 2022-11-27 15:41:51.571462: I Eval Time: 0.3310360908508301
# 2022-11-27 15:41:51.633933: I Results
# 2022-11-27 15:41:51.686091: I HR	0.0297
# 2022-11-27 15:41:51.704584: I nDCG	0.00779
# 2022-11-27 15:41:51.765585: I Precision	0.00059
# 2022-11-27 15:41:51.812965: I F1	0.00116
# 2022-11-27 15:41:51.880583: I MAP	0.00065
# 2022-11-27 15:41:51.947728: I ItemCoverage	1349
# 2022-11-27 15:41:52.024064: I nDCGRendle2020	0.00779
# 2022-11-27 15:41:52.070999: I Gini	0.52475
# 2022-11-27 15:41:52.140874: I SEntropy	9.87579
# 2022-11-27 15:41:52.208825: I EFD	0.00599
# 2022-11-27 15:41:52.249583: I EPC	0.0006
# 2022-11-27 15:41:52.322832: I
# 2022-11-27 15:41:52.381493: I Test Evaluation results
# 2022-11-27 15:41:52.422827: I Cut-off: 50
# 2022-11-27 15:41:52.525941: I Eval Time: 0.32657313346862793
# 2022-11-27 15:41:52.573593: I Results
# 2022-11-27 15:41:52.619098: I HR	0.02805
# 2022-11-27 15:41:52.685178: I nDCG	0.0085
# 2022-11-27 15:41:52.747349: I Precision	0.00056
# 2022-11-27 15:41:52.867050: I F1	0.0011
# 2022-11-27 15:41:52.914667: I MAP	0.0007
# 2022-11-27 15:41:52.938347: I ItemCoverage	1349
# 2022-11-27 15:41:53.040821: I nDCGRendle2020	0.0085
# 2022-11-27 15:41:53.064099: I Gini	0.52475
# 2022-11-27 15:41:53.090923: I SEntropy	9.87579
# 2022-11-27 15:41:53.149584: I EFD	0.00664
# 2022-11-27 15:41:53.167362: I EPC	0.00065
# 2022-11-27 15:41:53.276499: I
# 2022-11-27 15:41:53.301603: I Validation Evaluation results
# 2022-11-27 15:41:53.416142: I Cut-off: 100
# 2022-11-27 15:41:53.463442: I Eval Time: 0.7913820743560791
# 2022-11-27 15:41:53.498258: I Results
# 2022-11-27 15:41:53.566611: I HR	0.05941
# 2022-11-27 15:41:53.609179: I nDCG	0.01259
# 2022-11-27 15:41:53.676546: I Precision	0.00059
# 2022-11-27 15:41:53.697737: I F1	0.00118
# 2022-11-27 15:41:53.770223: I MAP	0.00063
# 2022-11-27 15:41:53.873233: I ItemCoverage	1389
# 2022-11-27 15:41:53.910204: I nDCGRendle2020	0.01259
# 2022-11-27 15:41:53.942417: I Gini	0.61995
# 2022-11-27 15:41:53.978357: I SEntropy	10.09361
# 2022-11-27 15:41:54.010917: I EFD	0.00593
# 2022-11-27 15:41:54.088894: I EPC	0.0006
# 2022-11-27 15:41:54.169986: I
# 2022-11-27 15:41:54.229345: I Test Evaluation results
# 2022-11-27 15:41:54.251241: I Cut-off: 100
# 2022-11-27 15:41:54.287532: I Eval Time: 0.7737231254577637
# 2022-11-27 15:41:54.342780: I Results
# 2022-11-27 15:41:54.399542: I HR	0.07096
# 2022-11-27 15:41:54.475513: I nDCG	0.01533
# 2022-11-27 15:41:54.478122: I Epoch 50/100 loss 0.09126
# 2022-11-27 15:41:54.487530: I Precision	0.00071
# 2022-11-27 15:41:54.485931: I Writing recommendations at: /Users/vuhoang/Documents/code_base/elliot/results/amazon_baby/recs
# 2022-11-27 15:41:54.500779: I F1	0.00141
# 2022-11-27 15:41:54.509481: I MAP	0.00066
# 2022-11-27 15:41:54.526049: I ItemCoverage	1389
# 2022-11-27 15:41:54.550272: I nDCGRendle2020	0.01533
# 2022-11-27 15:41:54.559888: I Gini	0.61995
# 2022-11-27 15:41:54.576282: I SEntropy	10.09361
# 2022-11-27 15:41:54.583101: I EFD	0.00729
# 2022-11-27 15:41:54.593413: I EPC	0.00073
#   0%|                                      | 0/20 [00:02<?, ?it/s, loss=3.19551]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [1], line 3
#       1 from elliot.run import run_experiment
# ----> 3 run_experiment("/Users/vuhoang/Documents/code_base/elliot/config_files/demo_amazon_baby.yml")
#
# File ~/Documents/code_base/elliot/elliot/run.py:82, in run_experiment(config_path)
#      80 logger.info(f"Tuning begun for {model_class.__name__}\\n")
#      81 trials = Trials()
# ---> 82 fmin(model_placeholder.objective,
#      83      space=model_base[1],
#      84      algo=model_base[3],
#      85      trials=trials,
#      86      verbose=False,
#      87      rstate=_rstate,
#      88      max_evals=model_base[2])
#      90 # argmin relativo alla combinazione migliore di iperparametri
#      91 min_val = np.argmin([i["result"]["loss"] for i in trials._trials])
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/fmin.py:507, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     504 validate_loss_threshold(loss_threshold)
#     506 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507     return trials.fmin(
#     508         fn,
#     509         space,
#     510         algo=algo,
#     511         max_evals=max_evals,
#     512         timeout=timeout,
#     513         loss_threshold=loss_threshold,
#     514         max_queue_len=max_queue_len,
#     515         rstate=rstate,
#     516         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     517         verbose=verbose,
#     518         catch_eval_exceptions=catch_eval_exceptions,
#     519         return_argmin=return_argmin,
#     520         show_progressbar=show_progressbar,
#     521         early_stop_fn=early_stop_fn,
#     522         trials_save_file=trials_save_file,
#     523     )
#     525 if trials is None:
#     526     if os.path.exists(trials_save_file):
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/base.py:682, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     677 # -- Stop-gap implementation!
#     678 #    fmin should have been a Trials method in the first place
#     679 #    but for now it's still sitting in another file.
#     680 from .fmin import fmin
# --> 682 return fmin(
#     683     fn,
#     684     space,
#     685     algo,
#     686     max_evals,
#     687     timeout=timeout,
#     688     loss_threshold=loss_threshold,
#     689     trials=self,
#     690     rstate=rstate,
#     691     verbose=verbose,
#     692     max_queue_len=max_queue_len,
#     693     allow_trials_fmin=False,  # -- prevent recursion
#     694     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     695     catch_eval_exceptions=catch_eval_exceptions,
#     696     return_argmin=return_argmin,
#     697     show_progressbar=show_progressbar,
#     698     early_stop_fn=early_stop_fn,
#     699     trials_save_file=trials_save_file,
#     700 )
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/fmin.py:553, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     550 rval.catch_eval_exceptions = catch_eval_exceptions
#     552 # next line is where the fmin is actually executed
# --> 553 rval.exhaust()
#     555 if return_argmin:
#     556     if len(trials.trials) == 0:
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/fmin.py:356, in FMinIter.exhaust(self)
#     354 def exhaust(self):
#     355     n_done = len(self.trials)
# --> 356     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     357     self.trials.refresh()
#     358     return self
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/fmin.py:292, in FMinIter.run(self, N, block_until_done)
#     289     time.sleep(self.poll_interval_secs)
#     290 else:
#     291     # -- loop over trials and do the jobs directly
# --> 292     self.serial_evaluate()
#     294 self.trials.refresh()
#     295 if self.trials_save_file != "":
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/fmin.py:170, in FMinIter.serial_evaluate(self, N)
#     168 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     169 try:
# --> 170     result = self.domain.evaluate(spec, ctrl)
#     171 except Exception as e:
#     172     logger.error("job exception: %s" % str(e))
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/hyperopt/base.py:907, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     898 else:
#     899     # -- the "work" of evaluating `config` can be written
#     900     #    either into the pyll part (self.expr)
#     901     #    or the normal Python part (self.fn)
#     902     pyll_rval = pyll.rec_eval(
#     903         self.expr,
#     904         memo=memo,
#     905         print_node_on_error=self.rec_eval_print_node_on_error,
#     906     )
# --> 907     rval = self.fn(pyll_rval)
#     909 if isinstance(rval, (float, int, np.number)):
#     910     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# File ~/Documents/code_base/elliot/elliot/hyperoptimization/model_coordinator.py:63, in ModelCoordinator.objective(self, args)
#      61 self.logger.info(f"Exploration: Train-Validation Fold exploration number {trainval_index+1}")
#      62 model = self.model_class(data=data_obj, config=self.base, params=model_params)
# ---> 63 model.train()
#      64 losses.append(model.get_loss())
#      65 results.append(model.get_results())
#
# File ~/Documents/code_base/elliot/elliot/recommender/visual_recommenders/VBPR/VBPR.py:124, in VBPR.train(self)
#     122 if steps == self._data.transactions // self._batch_size:
#     123     t.reset()
# --> 124     self.evaluate(it, loss.numpy() / steps)
#     125     it += 1
#     126     steps = 0
#
# File ~/Documents/code_base/elliot/elliot/recommender/recommender_utils_mixin.py:29, in RecMixin.evaluate(self, it, loss)
#      27 def evaluate(self, it=None, loss=0):
#      28     if (it is None) or (not (it + 1) % self._validation_rate):
# ---> 29         recs = self.get_recommendations(self.evaluator.get_needed_recommendations())
#      30         result_dict = self.evaluator.eval(recs)
#      32         self._losses.append(loss)
#
# File ~/Documents/code_base/elliot/elliot/recommender/visual_recommenders/VBPR/VBPR.py:135, in VBPR.get_recommendations(self, k)
#     133 offset_stop = min(offset + self._batch_eval, self._num_users)
#     134 predictions = np.empty((offset_stop - offset, self._num_items))
# --> 135 for batch in self._next_eval_batch:
#     136     item_rel, item_abs, feat = batch
#     137     p = self._model.predict_item_batch(offset, offset_stop,
#     138                                        item_rel[0], item_rel[-1],
#     139                                        tf.Variable(feat))
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:736, in OwnedIterator.__next__(self)
#     735 def __next__(self):  # For Python 3 compatibility
# --> 736   return self.next()
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:772, in OwnedIterator.next(self)
#     770 def next(self):
#     771   try:
# --> 772     return self._next_internal()
#     773   except errors.OutOfRangeError:
#     774     raise StopIteration
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py:755, in OwnedIterator._next_internal(self)
#     750 with context.execution_mode(context.SYNC):
#     751   with ops.device(self._device):
#     752     # TODO(ashankar): Consider removing this ops.device() context manager
#     753     # and instead mimic ops placement in graphs: Operations on resource
#     754     # handles execute on the same device as where the resource is placed.
# --> 755     ret = gen_dataset_ops.iterator_get_next(
#     756         self._iterator_resource,
#     757         output_types=self._flat_output_types,
#     758         output_shapes=self._flat_output_shapes)
#     760   try:
#     761     # Fast path for the case `self._structure` is not a nested structure.
#     762     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/elliot_env/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py:2604, in iterator_get_next(iterator, output_types, output_shapes, name)
#    2602 if tld.is_eager:
#    2603   try:
# -> 2604     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2605       _ctx._context_handle, tld.device_name, "IteratorGetNext", name,
#    2606       tld.op_callbacks, iterator, "output_types", output_types,
#    2607       "output_shapes", output_shapes)
#    2608     return _result
#    2609   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import hyperopt

# %%
# example of plotting the adagrad search on a contour plot of the test function
from math import sqrt
from numpy import asarray
from numpy import arange
from numpy.random import rand
from numpy.random import seed
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return x**2.0 + y**2.0

# derivative of objective function
def derivative(x, y):
	return asarray([x * 2.0, y * 2.0])

# gradient descent algorithm with adagrad
def adagrad(objective, derivative, bounds, n_iter, step_size):
	# track all solutions
	solutions = list()
	# generate an initial point
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# list of the sum square gradients for each variable
	sq_grad_sums = [0.0 for _ in range(bounds.shape[0])]
	# run the gradient descent
	for it in range(n_iter):
		# calculate gradient
		gradient = derivative(solution[0], solution[1])
		# update the sum of the squared partial derivatives
		for i in range(gradient.shape[0]):
			sq_grad_sums[i] += gradient[i]**2.0
		# build solution
		new_solution = list()
		for i in range(solution.shape[0]):
			# calculate the learning rate for this variable
			alpha = step_size / (1e-8 + sqrt(sq_grad_sums[i]))
			# calculate the new position in this variable
			value = solution[i] - alpha * gradient[i]
			new_solution.append(value)
		# store the new solution
		solution = asarray(new_solution)
		solutions.append(solution)
		# evaluate candidate point
		solution_eval = objective(solution[0], solution[1])
		# report progress
		print('>%d f(%s) = %.5f' % (it, solution, solution_eval))
	return solutions

# seed the pseudo random number generator
seed(1)
# define range for input
bounds = asarray([[-1.0, 1.0], [-1.0, 1.0]])
# define the total iterations
n_iter = 50
# define the step size
step_size = 0.1
# perform the gradient descent search
solutions = adagrad(objective, derivative, bounds, n_iter, step_size)
# sample input range uniformly at 0.1 increments
xaxis = arange(bounds[0,0], bounds[0,1], 0.1)
yaxis = arange(bounds[1,0], bounds[1,1], 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a filled contour plot with 50 levels and jet color scheme
pyplot.contourf(x, y, results, levels=50, cmap='jet')
# plot the sample as black circles
solutions = asarray(solutions)
pyplot.plot(solutions[:, 0], solutions[:, 1], '.-', color='w')
# show the plot
pyplot.show()
# Out:
# >0 f([-0.06595599  0.34064899]) = 0.12039
# >1 f([-0.02902286  0.27948766]) = 0.07896
# >2 f([-0.0129815   0.23463749]) = 0.05522
# >3 f([-0.00582483  0.1993997 ]) = 0.03979
# >4 f([-0.00261527  0.17071256]) = 0.02915
# >5 f([-0.00117437  0.14686138]) = 0.02157
# >6 f([-0.00052736  0.12676134]) = 0.01607
# >7 f([-0.00023681  0.10966762]) = 0.01203
# >8 f([-0.00010634  0.09503809]) = 0.00903
# >9 f([-4.77542704e-05  8.24607972e-02]) = 0.00680
# >10 f([-2.14444463e-05  7.16123835e-02]) = 0.00513
# >11 f([-9.62980437e-06  6.22327049e-02]) = 0.00387
# >12 f([-4.32434258e-06  5.41085063e-02]) = 0.00293
# >13 f([-1.94188148e-06  4.70624414e-02]) = 0.00221
# >14 f([-8.72017797e-07  4.09453989e-02]) = 0.00168
# >15 f([-3.91586740e-07  3.56309531e-02]) = 0.00127
# >16 f([-1.75845235e-07  3.10112252e-02]) = 0.00096
# >17 f([-7.89647442e-08  2.69937139e-02]) = 0.00073
# >18 f([-3.54597657e-08  2.34988084e-02]) = 0.00055
# >19 f([-1.59234984e-08  2.04577993e-02]) = 0.00042
# >20 f([-7.15057749e-09  1.78112581e-02]) = 0.00032
# >21 f([-3.21102543e-09  1.55077005e-02]) = 0.00024
# >22 f([-1.44193729e-09  1.35024688e-02]) = 0.00018
# >23 f([-6.47513760e-10  1.17567908e-02]) = 0.00014
# >24 f([-2.90771361e-10  1.02369798e-02]) = 0.00010
# >25 f([-1.30573263e-10  8.91375193e-03]) = 0.00008
# >26 f([-5.86349941e-11  7.76164047e-03]) = 0.00006
# >27 f([-2.63305247e-11  6.75849105e-03]) = 0.00005
# >28 f([-1.18239380e-11  5.88502652e-03]) = 0.00003
# >29 f([-5.30963626e-12  5.12447017e-03]) = 0.00003
# >30 f([-2.38433568e-12  4.46221948e-03]) = 0.00002
# >31 f([-1.07070548e-12  3.88556303e-03]) = 0.00002
# >32 f([-4.80809073e-13  3.38343471e-03]) = 0.00001
# >33 f([-2.15911255e-13  2.94620023e-03]) = 0.00001
# >34 f([-9.69567190e-14  2.56547145e-03]) = 0.00001
# >35 f([-4.35392094e-14  2.23394494e-03]) = 0.00000
# >36 f([-1.95516389e-14  1.94526160e-03]) = 0.00000
# >37 f([-8.77982370e-15  1.69388439e-03]) = 0.00000
# >38 f([-3.94265180e-15  1.47499203e-03]) = 0.00000
# >39 f([-1.77048011e-15  1.28438640e-03]) = 0.00000
# >40 f([-7.95048604e-16  1.11841198e-03]) = 0.00000
# >41 f([-3.57023093e-16  9.73885702e-04]) = 0.00000
# >42 f([-1.60324146e-16  8.48035867e-04]) = 0.00000
# >43 f([-7.19948720e-17  7.38448972e-04]) = 0.00000
# >44 f([-3.23298874e-17  6.43023418e-04]) = 0.00000
# >45 f([-1.45180009e-17  5.59929193e-04]) = 0.00000
# >46 f([-6.51942732e-18  4.87572776e-04]) = 0.00000
# >47 f([-2.92760228e-18  4.24566574e-04]) = 0.00000
# >48 f([-1.31466380e-18  3.69702307e-04]) = 0.00000
# >49 f([-5.90360555e-19  3.21927835e-04]) = 0.00000
